# %%
import src.modelling_fev1.pred_fev1 as pred_fev1

# %%
pred_fev1.calc_predicted_value_LMS_straight(178, 29, "Male")
# Out:
# {'M': 4.5275648718163,
#  'sigma_up': 0.5363464046714226,
#  'sigma_down': 0.5475914340867223,
#  'LLN': 3.6204016736591726,
#  'L': 1.1728201455488505,
#  'S': 0.11963746946768038}

# %%
pred_fev1.calc_predicted_value_LMS_straight(175, 30, "Male")
# Out:
# {'M': 4.3338337817790125,
#  'sigma_up': 0.5160637021935361,
#  'sigma_down': 0.5271266468150926,
#  'LLN': 3.4604162019972864,
#  'L': 1.1757017774412832,
#  'S': 0.12028487464044268}
