# %% [markdown]
# The modelling of O2 saturation is difficult because we observed trends/signals in the SmartCare data that are medically hard to explain, or counter intuitive. Hence, we're doing a complementary analysis on the O2 saturation patterns using the Breathe data.
#
# Boxplots of O2 saturation grouped by ID:
# - ordered by predicted FEV1
# - ordered by avg FEV1 % predicted
# - ordered by avg FEV1

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

import sys

sys.path.append("../data")
import breathe_data


plotsdir = "../../../../PlotsSmartcare/O2_FEV1/"

# %% [markdown]
# # Data processing

# %%
df = breathe_data.build_O2_FEV1_df()

# Remove when there's less than 10 O2 Saturation measurements
tmp_shape = df.shape[0]
tmp_ids = df.groupby("ID").size()
df = df.groupby("ID").filter(lambda x: len(x) >= 10)
print(
    f"Removed {tmp_shape - df.shape[0]}/{tmp_shape} rows, {tmp_ids.shape[0] - df.groupby('ID').size().shape[0]}/{tmp_ids.shape[0]} patients"
)


# Compute avg FEV1 % Predicted per individual
def compute_avg(df, col_name, unit):
    tmp = df.groupby("ID")[col_name].mean()
    # Add tmp to a new column per Id
    df = df.join(tmp, on="ID", rsuffix="_avg")

    df[f"ID (avg {col_name})"] = df.apply(
        lambda x: f"{x.ID} ({str(round(x[f'{col_name}_avg'],1))}{unit})",
        axis=1,
    )
    return df


df = compute_avg(df, "FEV1 % Predicted", "%")
df = compute_avg(df, "FEV1", "L")

# df[f"ID (Predicted FEV1)"] = df.apply(
#     lambda x: f"{x.ID} ({str(round(x['Predicted FEV1'],1))}L)",
#     axis=1,
# )
# Out:
# *** Building O2 Saturation and FEV1 dataframe ***
#
# *** Loading patients data ***
# Warning - 4 NaN values in dataframe
# The 4 NaN values belong to IDs ('322', '338', '344', '348') whose height are missing.
# However, we don't correct for them as we don't have any measurement corresponding to those IDs for now.
# Loaded 258 individuals
#
# *** Loading measurements data ***
# Dropping 1 entries with FEV1 = 6.0 for ID 330
# * Checking for same day measurements *
# * Checking for same day measurements *
# Number of IDs:  233
# Number of rows:  26812
# Number of FEV1 recordings: 23778
# Number of O2 Saturation recordings: 23431
# Dropped 0 entries with NaN O2 Saturation and NaN FEV1
# Dropped 3381 entries with NaN O2 Saturation
# Dropped 3034 entries with NaN FEV1
# 20397 entries remain
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 125.39378062710472
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 132.27514663712876
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 131.2556850060141
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.33539573376069
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.84512654931802
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 123.8645881804327
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.08053032598202
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.57079951042469
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.55133787931003
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.57079951042469
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 125.64864603488337
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.84512654931802
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.31593410264601
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.55133787931003
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 127.1778384815554
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 133.03974286046474
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 132.02028122935008
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 129.98135796712074
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 126.15837685044072
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 127.68756929711272
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 124.8840498115474
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.59026114153934
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.31593410264601
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 128.7070309282274
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.84512654931802
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 124.8840498115474
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 131.76541582157142
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 132.02028122935008
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 134.0592044915794
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 124.11945358821137
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 130.74595419045673
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 128.19730011267006
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 129.47162715156338
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 125.13891521932605
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 131.76541582157142
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.06106869486734
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.55133787931003
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 127.94243470489137
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.57079951042469
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 125.13891521932605
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 126.41324225821937
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.08053032598202
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.80620328708869
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.29647247153135
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 128.7070309282274
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 131.2556850060141
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.59026114153934
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 121.06106869486734
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.84512654931802
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 123.35485736487537
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 127.68756929711272
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 126.66810766599805
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 123.35485736487537
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.08053032598202
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 128.96189633600605
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 120.29647247153135
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 127.1778384815554
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 126.41324225821937
# Warning for ID 113: FEV1 % Predicted should be in 0-120%, got 122.08053032598202
# Warning for ID 126: FEV1 % Predicted should be in 0-120%, got 121.51034664834964
# Warning for ID 126: FEV1 % Predicted should be in 0-120%, got 120.81600181035907
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 147.24696075623552
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 135.50333811923517
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 135.50333811923517
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 135.50333811923517
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 149.50534972488947
# Warning for ID 202: FEV1 % Predicted should be in 0-120%, got 126.46978224461947
# Warning for ID 331: FEV1 % Predicted should be in 0-120%, got 122.1393724967138
# Built data structure with 213 IDs and 20397 entries
# Removed 148/20397 rows, 39/213 patients

# %% [markdown]
# # O2_Saturation boxplots per individual

# %%
df
# Out:
#         ID Date Recorded  FEV1  O2 Saturation  Age   Sex  Height  \
# 0      101    2019-02-20  1.31           97.0   53  Male   173.0
# 1      101    2019-02-21  1.29           96.0   53  Male   173.0
# 2      101    2019-02-22  1.32           96.0   53  Male   173.0
# 3      101    2019-02-23  1.28           97.0   53  Male   173.0
# 4      101    2019-02-24  1.33           98.0   53  Male   173.0
# ...    ...           ...   ...            ...  ...   ...     ...
# 20392  358    2021-06-05  4.33           99.0   18  Male   177.0
# 20393  358    2021-06-09  4.35           99.0   18  Male   177.0
# 20394  358    2021-06-10  4.30           98.0   18  Male   177.0
# 20395  358    2021-06-12  4.30           97.0   18  Male   177.0
# 20396  358    2021-06-14  4.29           99.0   18  Male   177.0
#
#        Predicted FEV1  Healthy O2 Saturation  FEV1 % Predicted  \
# 0            3.610061              97.397202         36.287474
# 1            3.610061              97.397202         35.733466
# 2            3.610061              97.397202         36.564477
# 3            3.610061              97.397202         35.456463
# 4            3.610061              97.397202         36.841481
# ...               ...                    ...               ...
# 20392        4.505342              97.363734         96.108129
# 20393        4.505342              97.363734         96.552046
# 20394        4.505342              97.363734         95.442252
# 20395        4.505342              97.363734         95.442252
# 20396        4.505342              97.363734         95.220294
#
#        O2 Saturation % Healthy  FEV1 % Predicted_avg  \
# 0                    99.592183             41.090567
# 1                    98.565459             41.090567
# 2                    98.565459             41.090567
# 3                    99.592183             41.090567
# 4                   100.618906             41.090567
# ...                        ...                   ...
# 20392               101.680570             95.724745
# 20393               101.680570             95.724745
# 20394               100.653493             95.724745
# 20395                99.626417             95.724745
# 20396               101.680570             95.724745
#
#       ID (avg FEV1 % Predicted)  FEV1_avg ID (avg FEV1)
# 0                   101 (41.1%)  1.483395    101 (1.5L)
# 1                   101 (41.1%)  1.483395    101 (1.5L)
# 2                   101 (41.1%)  1.483395    101 (1.5L)
# 3                   101 (41.1%)  1.483395    101 (1.5L)
# 4                   101 (41.1%)  1.483395    101 (1.5L)
# ...                         ...       ...           ...
# 20392               358 (95.7%)  4.312727    358 (4.3L)
# 20393               358 (95.7%)  4.312727    358 (4.3L)
# 20394               358 (95.7%)  4.312727    358 (4.3L)
# 20395               358 (95.7%)  4.312727    358 (4.3L)
# 20396               358 (95.7%)  4.312727    358 (4.3L)
#
# [20249 rows x 15 columns]

# %%
# Parametrisation
## O2 Saturation
O2_col = "O2 Saturation"
O2_col = "O2 Saturation % Healthy"

# Sort values by ascending FEV1 % Predicted
FEV1_col = "FEV1 % Predicted"
# FEV1_col = "Predicted FEV1"
# FEV1_col = "FEV1"

gender = "both"
# gender = "male"
# gender = "female"

if gender == "both":
    df_plot = df
    title_suffix = ""
elif gender == "male":
    df_plot = df[df.Sex == "Male"]
    title_suffix = ", males only"
elif gender == "female":
    df_plot = df[df.Sex == "Female"]
    title_suffix = ", females only"

df_plot = df_plot.sort_values(
    by=[FEV1_col if FEV1_col == "Predicted FEV1" else f"{FEV1_col}_avg"]
)

title = f"Breathe - Boxplots for {O2_col}, ordered by {FEV1_col} ({df_plot.shape[0]} points{title_suffix})"

fig = px.box(
    df_plot,
    x=f"ID ({FEV1_col if FEV1_col == 'Predicted FEV1' else 'avg ' + FEV1_col})",
    y=O2_col,
)
# Add title
fig.update_layout(title=title)
fig.update_traces(boxmean=True)

# Update fig size
fig.update_layout(height=600, width=3000)
fig.show()
# fig.write_image("{}/Factors - {}.pdf".format(plotsdir, title))

# %%
col = "mean FEV1 % Predicted"
col = "Predicted FEV1"
# col = 'mean FEV1'
col = "Height"
col = "Age"

O2_sat_is_sex_corrected = True
# O2_sat_is_sex_corrected = False

n = 5
O2_type = "mean"
O2_type = f"rmax-{n}"
O2_colname = (
    f"Sex corrected O2 Saturation {O2_type} agg"
    if O2_sat_is_sex_corrected
    else f"O2 Saturation {O2_type} agg"
)

# Get the FEV1 % Predicted for the each patient
sexes = df.groupby("ID")["Sex"].first()
heights = df.groupby("ID")["Height"].first()
ages = df.groupby("ID")["Age"].first()

# Create a df with means and fev1
df_agg = pd.DataFrame({"ID": sexes.index, "Sex": sexes, "Height": heights, "Age": ages})


def get_rmax(s_O2_Saturation_for_ID):
    return s_O2_Saturation_for_ID.nlargest(n).iloc[-1]


def apply_correction(row, mean_m, mean_f, std_m, std_f, O2_colname):
    if row.Sex == "Male":
        return (row[O2_colname] - mean_m) / std_m
    if row.Sex == "Female":
        return (row[O2_colname] - mean_f) / std_f


def correct_O2_Saturation_for_sex(df, O2_colname):
    O2_Saturation_mean_m = df[df.Sex == "Male"][O2_colname].mean()
    O2_Saturation_mean_f = df[df.Sex == "Female"][O2_colname].mean()
    O2_Saturation_std_m = df[df.Sex == "Male"][O2_colname].std()
    O2_Saturation_std_f = df[df.Sex == "Female"][O2_colname].std()

    return df.apply(
        lambda row: apply_correction(
            row,
            O2_Saturation_mean_m,
            O2_Saturation_mean_f,
            O2_Saturation_std_m,
            O2_Saturation_std_f,
            O2_colname,
        ),
        axis=1,
    )


df_agg["Predicted FEV1"] = df.groupby("ID")["Predicted FEV1"].first()
df_agg["mean FEV1 % Predicted"] = df.groupby("ID")["FEV1 % Predicted"].mean()
df_agg[f"O2 Saturation rmax-{n} agg"] = df.groupby("ID")["O2 Saturation"].apply(
    get_rmax
)
df_agg[f"O2 Saturation mean agg"] = df.groupby("ID")["O2 Saturation"].mean()
df_agg[f"Sex corrected O2 Saturation {O2_type} agg"] = correct_O2_Saturation_for_sex(
    df_agg, f"O2 Saturation {O2_type} agg"
)

# Order by lung function variable
df_agg = df_agg.sort_values(by=col)

# Scatter plot of means
fig = px.scatter(x=df_agg[col], y=df_agg[O2_colname], color=df_agg.Sex)
# fig = px.scatter(x=df_agg[col], y=df_agg[f"O2_Saturation {O2_type} agg"], color=df_agg.Sex)
# Update font size
fig.update_layout(
    font=dict(
        size=8,
    ),
)


# Compute Pearson correlation coefficient
def calc_bootstrapped_corr(df, var1, var2, size=0.9, n=2000):
    """
    Calculate Pearson correlation coefficient by bootstrapping n times with 90% of the data
    """
    corr_all = []
    corr_m = []
    corr_f = []
    for i in range(n):
        sample_all = df.sample(frac=size)
        sample_m = sample_all[sample_all.Sex == "Male"]
        sample_f = sample_all[sample_all.Sex == "Female"]
        corr_all.append(sample_all[[var1, var2]].corr().loc[var1, var2])
        corr_m.append(sample_m[[var1, var2]].corr().loc[var1, var2])
        corr_f.append(sample_f[[var1, var2]].corr().loc[var1, var2])
    # Return max min string for corr_all, corr_m, corr_f
    return (
        f"[{round(np.min(corr_all), 2)};{round(np.max(corr_all), 2)}]",
        f"[{round(np.min(corr_m), 2)};{round(np.max(corr_m), 2)}]",
        f"[{round(np.min(corr_f), 2)};{round(np.max(corr_f), 2)}]",
    )


print(
    f"Calculating Bootstrapped Pearson correlation coefficients for {col} and {O2_colname}"
)
corr_all_range, corr_m_range, corr_f_range = calc_bootstrapped_corr(
    df_agg, col, O2_colname
)

# title = f"Breathe - {O2_colname} vs {col} ({len(df_agg)} individuals, Pearson corr: all={round(corr_all, 2)}, males={round(corr_m,2)}, females={round(corr_f,2)}"
title = f"Breathe - {O2_colname} vs {col} ({len(df_agg)} IDs, boots. corr.: all={corr_all_range}, m={corr_m_range}, f={corr_f_range}"

# Add Pearson correlation coefficient to title
fig.update_layout(title=title, width=800, height=300)
# Reduce marker size
fig.update_traces(marker=dict(size=3))
# Set axis labels
fig.update_xaxes(title_text=f"{col}")
# fig.update_xaxes(title_text=f'{len(df_agg)} individuals (ordered by FEV1 % Predicted)', showgrid=False, showticklabels=False)
# Put the x axis title on bottom
if O2_sat_is_sex_corrected:
    fig.update_yaxes(title_text=O2_colname)
if not (O2_sat_is_sex_corrected):
    fig.update_yaxes(
        range=[90, 101], nticks=10, title_text=f"O2_Saturation {O2_type} agg"
    )
fig.show()
# Save fig
# fig.write_image(f"{plotsdir}/Factors - {title}.pdf")
# Out:
# Calculating Bootstrapped Pearson correlation coefficients for Age and Sex corrected O2 Saturation rmax-5 agg

# %% [markdown]
# # Study the 60% FEV1 % Predicted cut-off

# %%
# Split dataframe into 2 based on FEV1 % Predicted = 60%
df_low = df[df["FEV1 % Predicted"] <= 60]
df_high = df[df["FEV1 % Predicted"] > 60]

# For each individual, compute the average O2 saturation
means_low = df_low.groupby("ID")["O2 Saturation"].mean()
means_high = df_high.groupby("ID")["O2 Saturation"].mean()


# Compute the achievable range of values between 75th percentile and 25th percentile
achievable_ranges_low = df_low.groupby("ID")["O2 Saturation"].quantile(
    0.75
) - df_low.groupby("ID")["O2 Saturation"].quantile(0.25)
achievable_ranges_high = df_high.groupby("ID")["O2 Saturation"].quantile(
    0.75
) - df_high.groupby("ID")["O2 Saturation"].quantile(0.25)

# %%
# Compare mean of means_low with mean of means_high
print(f"Mean of means_low: {means_low.mean()}")
print(f"Mean of means_high: {means_high.mean()}")

# Same for achievable ranges
print(f"Mean of achievable_ranges_low: {achievable_ranges_low.mean()}")
print(f"Mean of achievable_ranges_high: {achievable_ranges_high.mean()}")
# Out:
# Mean of means_low: 96.45465785082783
# Mean of means_high: 97.44298835023817
# Mean of achievable_ranges_low: 1.225
# Mean of achievable_ranges_high: 0.9890510948905109

# %%
# Plot a boxplot of the achievable_ranges_low and achievable_ranges_high side by side
fig = go.Figure()
fig.add_trace(
    go.Box(y=achievable_ranges_low, name="FEV1 % Predicted <60%", boxmean=True)
)
fig.add_trace(
    go.Box(y=achievable_ranges_high, name="FEV1 % Predicted >60%", boxmean=True)
)
# Update fig size
fig.update_layout(
    title="Achievable ranges of O2 saturation (75th-25th percentiles)",
    height=600,
    width=600,
)
fig.show()

# %% [markdown]
# # Study O2_Saturation sex bias

# %%
df_males = df[df.Sex == "Male"]
df_females = df[df.Sex == "Female"]
assert len(df_males) + len(df_females) == len(df)

# %%
df_females["O2 Saturation"].describe()
# Out:
# count    10994.000000
# mean        97.147929
# std          1.746038
# min         76.000000
# 25%         96.000000
# 50%         98.000000
# 75%         98.000000
# max        100.000000
# Name: O2 Saturation, dtype: float64

# %%
df_males["O2 Saturation"].describe()
# Out:
# count    9255.000000
# mean       96.748664
# std         1.496404
# min        89.000000
# 25%        96.000000
# 50%        97.000000
# 75%        98.000000
# max       100.000000
# Name: O2 Saturation, dtype: float64

# %% [markdown]
# Conclusions:
#
# All: mean female O2_Saturation - mean male O2_Saturation = 97.2 (1.7%) - 96.8 (1.5%) = 0.4%
#
# \>60% FEV1 % Predicted avg: 97.6 (1.3%) - 97.2 (1.2%) = 0.4%
#
# \>80% FEV1 % Predicted avg: 97.9 (1.2%) - 97.3 (1.1%) = 0.6%
#
# \>90% FEV1 % Predicted avg: 98.2 (0.9%) - 97.2 (1.2%) = 1%
#
# ____________
# Only within 18-40yr range (this excludes 20 females and 10 males)
#
# All: 97.2 (1.7%) - 96.8 (1.5%) = 0.4%
#
# \>90% FEV1 % Predicted avg: 98 (0.9%) - 97.2 (1.2%) = 0.8%

# %%
# Threshold for healthy individuals
threshold_fev1_prct_pred = 60
df_healthy_males = df_males[
    df_males["FEV1 % Predicted_avg"] >= threshold_fev1_prct_pred
]
df_healthy_females = df_females[
    df_females["FEV1 % Predicted_avg"] >= threshold_fev1_prct_pred
]

# %%
df_healthy_females["O2 Saturation"].describe()
# Out:
# count    5576.000000
# mean       97.622788
# std         1.385999
# min        88.000000
# 25%        97.000000
# 50%        98.000000
# 75%        98.000000
# max       100.000000
# Name: O2 Saturation, dtype: float64

# %%
df_healthy_males["O2 Saturation"].describe()
# Out:
# count    5191.000000
# mean       97.194259
# std         1.189012
# min        91.000000
# 25%        97.000000
# 50%        97.000000
# 75%        98.000000
# max       100.000000
# Name: O2 Saturation, dtype: float64

# %%
# Within 18-40 age range
df_young_males = df_males[(df_males["Age"] >= 18) & (df_males["Age"] <= 40)]
df_young_females = df_females[(df_females.Age >= 18) & (df_females.Age <= 40)]
# Print length diff against df_males and df_females
print(
    f"{len(df_young_females.ID.unique())}/{len(df_females.ID.unique())} females between 18 and 40"
)
print(
    f"{len(df_young_males.ID.unique())}/{len(df_males.ID.unique())} males between 18 and 40"
)
# Out:
# 77/97 females between 18 and 40
# 63/77 males between 18 and 40

# %%
df_young_females["O2 Saturation"].describe()
# Out:
# count    7943.000000
# mean       97.185362
# std         1.752879
# min        76.000000
# 25%        96.875000
# 50%        98.000000
# 75%        98.000000
# max       100.000000
# Name: O2 Saturation, dtype: float64

# %%
df_young_males["O2 Saturation"].describe()
# Out:
# count    6533.000000
# mean       96.775815
# std         1.547469
# min        89.000000
# 25%        96.000000
# 50%        97.000000
# 75%        98.000000
# max       100.000000
# Name: O2 Saturation, dtype: float64

# %%
# Threshold for healthy individuals
threshold_fev1_prct_pred = 90
df_young_males[df_young_males["FEV1 % Predicted_avg"] >= threshold_fev1_prct_pred][
    "O2 Saturation"
].describe()
# Out:
# count    956.000000
# mean      97.284414
# std        1.125001
# min       93.000000
# 25%       97.000000
# 50%       98.000000
# 75%       98.000000
# max      100.000000
# Name: O2 Saturation, dtype: float64

# %%
df_young_females[df_young_females["FEV1 % Predicted_avg"] >= threshold_fev1_prct_pred][
    "O2 Saturation"
].describe()
# Out:
# count    993.000000
# mean      98.008056
# std        0.967171
# min       89.000000
# 25%       98.000000
# 50%       98.000000
# 75%       99.000000
# max      100.000000
# Name: O2 Saturation, dtype: float64

# %% [markdown]
# # Factors
# ## Healthy O2 Saturation Factor

# %%
df.head()
# Out:
#     ID Date Recorded  FEV1  O2 Saturation  Age   Sex  Height  Predicted FEV1  \
# 0  101    2019-02-20  1.31           97.0   53  Male   173.0        3.610061
# 1  101    2019-02-21  1.29           96.0   53  Male   173.0        3.610061
# 2  101    2019-02-22  1.32           96.0   53  Male   173.0        3.610061
# 3  101    2019-02-23  1.28           97.0   53  Male   173.0        3.610061
# 4  101    2019-02-24  1.33           98.0   53  Male   173.0        3.610061
#
#    Healthy O2 Saturation  FEV1 % Predicted  O2 Saturation % Healthy  \
# 0              97.397202         36.287474                99.592183
# 1              97.397202         35.733466                98.565459
# 2              97.397202         36.564477                98.565459
# 3              97.397202         35.456463                99.592183
# 4              97.397202         36.841481               100.618906
#
#    FEV1 % Predicted_avg ID (avg FEV1 % Predicted)  FEV1_avg ID (avg FEV1)
# 0             41.090567               101 (41.1%)  1.483395    101 (1.5L)
# 1             41.090567               101 (41.1%)  1.483395    101 (1.5L)
# 2             41.090567               101 (41.1%)  1.483395    101 (1.5L)
# 3             41.090567               101 (41.1%)  1.483395    101 (1.5L)
# 4             41.090567               101 (41.1%)  1.483395    101 (1.5L)

# %% [markdown]
# ## Fit O2 saturation with sex, height

# %%
# Fit O2 Saturation = a + b*isMale
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from plotly.subplots import make_subplots

model_type = "sex"  # baseline
# model_type = "sex and height"  # Difficult to interprete as height/sex can be dependent in their relation to O2 Sat
model_type = "sex then height"  # Ensure sex captures all relationship with O2 Sat, then fit height
# model_type = "sex then height (no height intercept)"

# Compute isMale
df["isMale"] = pd.get_dummies(df.Sex).Male

# Values from literature
female_o2_sat_min = 98.3
female_o2_sat_max = 98.6
male_o2_sat_min = 97.1
male_o2_sat_max = 97.9
delta_min = -0.5
delta_max = -1.5


def fit_O2sat_by_sex(df, with_height: bool):
    """
    Run a Linear Regression (OLS) to learn the parameters of the model for healthy O2 Saturation
    O2 Saturation = a + b*isMale (+ c*Height)
    """
    if with_height:
        X = np.array([df.isMale, df["Height"]]).T
    else:
        X = np.array([df.isMale]).T

    Y = df["O2 Saturation"]

    regr = (
        linear_model.LinearRegression()
    )  # Do not use fit_intercept = False if you have removed 1 column after dummy encoding
    regr.fit(X, Y)
    return regr


def compute_O2Sat_residual_after_sex_fit(row, intercept, isMaleScale):
    return row["O2 Saturation"] - intercept - isMaleScale * row.isMale


def compute_O2Sat_residual_after_sex_height_fit(
    row, intercept, isMaleScale, heightScale
):
    return (
        row["O2 Saturation"]
        - intercept
        - isMaleScale * row.isMale
        - heightScale * (row.Height - df.Height.mean())
    )


def further_fit_O2sat_by_height(df, a: float, b: float, with_intercept: bool):
    """
    a: intercept
    b: coefficient of isMale

    Once we have fit O2 Saturation = a + b*isMale, we can compute the residuals of this fit
    We then fit those residuals against Height to capture the remaining relationship of O2 Sat with height
    Id est we fit O2 Saturation - a - b*isMale = c*Height + d using an OLS
    """
    O2Sat_residuals = df.apply(
        lambda x: compute_O2Sat_residual_after_sex_fit(x, a, b), axis=1
    )
    Height_scaled = df.Height - df.Height.mean()

    X = np.array([Height_scaled]).T
    Y = O2Sat_residuals

    regr = linear_model.LinearRegression(fit_intercept=with_intercept)
    regr.fit(X, Y)
    return regr


health_thresholds = range(10, 95, 5)  # avg FEV1 % Predicted
a = []
b = []
if (
    model_type == "sex and height"
    or model_type == "sex then height (no height intercept)"
):
    c = []
if model_type == "sex then height":
    c = []
    d = []
n_IDs = []
n_m_IDs = []
n_f_IDs = []
n_datapoints = []
valid_health_thresholds = []


def filter_healthiest(df, health_threshold):
    """
    Filter healthiest individuals
    """
    return df[df["FEV1 % Predicted_avg"] >= health_threshold]


for health_threshold in health_thresholds:
    df_healthiest = filter_healthiest(df, health_threshold)

    if len(df_healthiest) == 0:
        continue

    n_IDs.append(len(df_healthiest.ID.unique()))
    n_m_IDs.append(len(df_healthiest[df_healthiest.Sex == "Male"].ID.unique()))
    n_f_IDs.append(len(df_healthiest[df_healthiest.Sex == "Female"].ID.unique()))
    n_datapoints.append(len(df_healthiest))
    valid_health_thresholds.append(health_threshold)

    regr = fit_O2sat_by_sex(df_healthiest, model_type == "sex and height")
    tmp_a = regr.intercept_
    tmp_b = regr.coef_[0]
    a.append(tmp_a)
    b.append(tmp_b)
    if model_type == "sex and height":
        c.append(regr.coef_[1])
    elif model_type == "sex then height":
        # In this case, we fit O2 Saturation - a - b*isMale = c*Height + d
        regr_height = further_fit_O2sat_by_height(
            df_healthiest,
            tmp_a,
            tmp_b,
            True,
        )
        c.append(regr_height.coef_[0])
        d.append(regr_height.intercept_)
    elif model_type == "sex then height (no height intercept)":
        # In this case, we fit O2 Saturation - a - b*isMale = c*Height
        regr_height = further_fit_O2sat_by_height(
            df_healthiest,
            tmp_a,
            tmp_b,
            False,
        )
        c.append(regr_height.coef_[0])

prct_datapoints = np.array(n_datapoints) / len(df) * 100
prct_females = np.array(n_f_IDs) / np.array(n_IDs) * 100

X_chart = [
    f"{t}% ({int(datapoints)}%, {int(females)}%)"
    for t, datapoints, females in zip(
        valid_health_thresholds, prct_datapoints, prct_females
    )
]

title = "Breathe - Fitting O2 Saturation = a + b*isMale"
nrows = 3
fig_height = 600
if model_type == "sex and height":
    nrows = 3
    title = "Breathe - Fitting O2 Saturation = a + b*isMale + c*Height"
    fig_height = 600
if model_type == "sex then height":
    nrows = 4
    title = f"Breathe - Fitting O2 Saturation = a + b*isMale + c*(Height - avg_height)"
    fig_height = 600
if model_type == "sex then height (no height intercept)":
    nrows = 4
    title = f"Breathe - Fitting O2 Saturation = b*isMale + c*(Height - avg_height)"
    fig_height = 600

fig = make_subplots(
    rows=nrows,
    cols=1,
    shared_xaxes=True,
    vertical_spacing=0.04,
)

# a
fig.add_trace(
    go.Scatter(
        x=X_chart, y=a, name="a (Female O2 Saturation, without height component)"
    ),
    row=1,
    col=1,
)
# Add annotation below the point a[-3] to show the value of a[-3]
fig.add_annotation(
    x=X_chart[-3],
    y=a[-3],
    text=f"a={round(a[-3], 2)}",
    showarrow=True,
    arrowhead=1,
    row=1,
    col=1,
)
fig.add_shape(
    type="rect",
    opacity=0.1,
    fillcolor="blue",
    line_color="blue",
    x0=0,
    y0=female_o2_sat_min,
    x1=len(X_chart) - 1,
    y1=female_o2_sat_max,
    row=1,
    col=1,
    layer="below",
)

# b
fig.add_trace(go.Scatter(x=X_chart, y=b, name="b"), row=3, col=1)
fig.update_traces(row=3, col=1, marker_color="black")
# Add annotation below the point b[-3] to show the value of b[-3]
fig.add_annotation(
    x=X_chart[-3],
    y=b[-3],
    text=f"b={round(b[-3], 2)}",
    showarrow=True,
    arrowhead=1,
    row=3,
    col=1,
)
fig.add_shape(
    type="rect",
    opacity=0.1,
    fillcolor="black",
    line_color="black",
    x0=0,
    y0=delta_min,
    x1=len(X_chart) - 1,
    y1=delta_max,
    row=3,
    col=1,
    layer="below",
)

# Other
if model_type == "sex":
    fig.add_trace(
        go.Scatter(x=X_chart, y=np.array(b) + np.array(a), name="a+b"), row=2, col=1
    )
    fig.update_traces(row=2, col=1, marker_color="red")
elif model_type == "sex and height":
    fig.add_trace(go.Scatter(x=X_chart, y=c, name="c"), row=3, col=1)
elif (
    model_type == "sex then height"
    or model_type == "sex then height (no height intercept)"
):
    fig.add_trace(
        go.Scatter(
            x=X_chart,
            y=np.array(b) + np.array(a),
            name="a+b (Male O2 Saturation, without height component)",
        ),
        row=2,
        col=1,
    )
    fig.update_traces(row=2, col=1, marker_color="red")
    fig.add_annotation(
        x=X_chart[-3],
        y=b[-3]+a[-3],
        text=f"a+b={round(b[-3]+a[-3], 2)}",
        showarrow=True,
        arrowhead=1,
        row=2,
        col=1,
    )
    fig.add_shape(
        type="rect",
        opacity=0.1,
        fillcolor="red",
        line_color="red",
        x0=0,
        y0=male_o2_sat_min,
        x1=len(X_chart) - 1,
        y1=male_o2_sat_max,
        row=2,
        col=1,
        layer="below",
    )
    # Add c with color green
    fig.add_trace(
        go.Scatter(x=X_chart, y=c, name="c (Height component)", marker_color="green"),
        row=4,
        col=1,
    )
    # Add annotation below the point c[-3] to show the value of c[-3]
    fig.add_annotation(
        x=X_chart[-3],
        y=c[-3],
        text=f"c={round(c[-3], 3)}",
        showarrow=True,
        arrowhead=1,
        row=4,
        col=1,
    )
    # if model_type == "sex then height":
    #     fig.add_trace(go.Scatter(x=X_chart, y=d, name="d"), row=5, col=1)


# Update y axis names for each subplot
fig.update_yaxes(title="a (%)", nticks=5, row=1, col=1, range=[96, 100])
fig.update_yaxes(title="b (%)", nticks=5, row=3, col=1, range=[-3, 1])
if model_type == "sex":
    fig.update_yaxes(title="a+b", nticks=5, row=2, col=1, range=[96, 100])
if model_type == "sex and height":
    fig.update_yaxes(title="c", nticks=5, row=2, col=1)
elif model_type == "sex then height" or "sex then height (no height intercept)":
    fig.update_yaxes(title="a+b (%)", nticks=5, row=2, col=1, range=[96, 100])
    fig.update_yaxes(title="c (%/cm)", nticks=5, row=4, col=1)
    # if model_type == "sex then height":
    # fig.update_yaxes(title="d", nticks=5, row=5, col=1)

fig.update_layout(title=title, showlegend=False, height=fig_height, width=800)
fig.update_xaxes(
    title_text="Individuals' healthiness threshold, i.e. avg FEV1 % Predicted (%datapoints, %females)"
)
fig.show()
fig.write_image(f"{plotsdir}/Factors - {title}.pdf")
print(avg_height)
# Out:
# 164.77914110429447

# %%
# Selected 80% threshold
df_healthiest = filter_healthiest(df, 80)
avg_height = df_healthiest.Height.mean()
print(avg_height)

# Calculate Residual Standard Error (RSE)

# RSE = sqrt(SSR / (n - p - 1))

# SSR: Sum of squared residuals.
# n: Total number of observations.
# p: Number of predictor variables (including the intercept).
# The degrees of freedom for the residuals is (n - p - 1).

df_healthiest["(O2Sat - a)/b"] = df_healthiest.apply(
    lambda x: compute_O2Sat_residual_after_sex_fit(x, a[-3], b[-3]), axis=1
)
df_healthiest["O2Sat fit residuals"] = df_healthiest.apply(
    lambda x: compute_O2Sat_residual_after_sex_height_fit(x, a[-3], b[-3], c[-3]),
    axis=1,
)

# Compute total sum of squares of O2 Saturation
tss = np.sum(
    (df_healthiest["O2 Saturation"] - df_healthiest["O2 Saturation"].mean()) ** 2
)
print(f"Total sum of squares: {tss:.4f}")

# Compute RSS of those residuals
n = len(df_healthiest)
## For the fit O2 Saturation = a + b*isMale
rss = np.sum(df_healthiest["(O2Sat - a)/b"] ** 2)
p = 2  # intercept, isMale
rse = np.sqrt(rss / (n - p - 1))
print(f"For the sex fit: RSS={rss:.4f}, RSE={rse:.4f}")
r2 = 1 - rss / tss
print(f"R2 = {r2:.4f}")

## For the fit O2 Saturation = a + b*isMale + c*Height
rss_full = np.sum(df_healthiest["O2Sat fit residuals"] ** 2)
p = 3  # intercept, isMale, Height
rse_full = np.sqrt(rss_full / (n - p - 1))
print(f"For the sex, height fit, RSS={rss_full:.4f}, RSE={rse_full:.4f}")
r2_full = 1 - rss_full / tss
print(f"R2 = {r2_full:.4f}")

### Compute relative improvement in R2
print(f"Relative improvement in R2: {(r2_full - r2) / r2 * 100:.2f}%")
# Out:
# 164.77914110429447
# Total sum of squares: 4492.9555
# For the sex fit: RSS=4008.6304, RSE=1.0345
# R2 = 0.1078
# For the sex, height fit, RSS=3976.0461, RSE=1.0304
# R2 = 0.1150
# Relative improvement in R2: 6.73%
# /var/folders/zq/v2r6yn111s3gpdf8lzf72xvw0000gn/T/ipykernel_68361/3097075086.py:15: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/zq/v2r6yn111s3gpdf8lzf72xvw0000gn/T/ipykernel_68361/3097075086.py:18: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Using the 80% healthiest individuals, compute the std dev of O2 Saturation measurements
# This is the noise of the measurement
# Then compute the std dev of the residuals of the fit
# This is the noise of the model
# Compare the 2
# If the noise of the model is smaller than the noise of the measurement, then the model is useful
# If the noise of the model is bigger than the noise of the measurement, then the model is not useful
df_healthiest = filter_healthiest(df, 80)
df_healthiest["O2 Saturation"].std()
# Out:
# 1.0948793582851426

# %%
print("a =", a[-3], "\nb =", b[-3], "\nc =", c[-3], "\navg height =", avg_height)
# Out:
# a = 98.06752062527138
# b = -0.7384058258246333
# c = -0.012547943971150761
# avg height = 164.77914110429447

# %% [markdown]
# ## Plot residuals of O2 Sat fit by Sex

# %%
df_healthiest.Height.mean()
# Out:
# 164.77914110429447

# %%
# Plot the residuals of the fit O2 Saturation = a + b*isMale against Height

df_healthiest = filter_healthiest(df, 80)
df_healthiest["(O2Sat - a)/b"] = df_healthiest.apply(
    lambda x: compute_O2Sat_residual_after_sex_fit(x, a[-3], b[-3]), axis=1
)
df_healthiest["Height - mean_height"] = (
    df_healthiest.Height - df_healthiest.Height.mean()
)

# Compute an print correlation between those residuals and height
print(
    f"Correlation between (O2Sat - a)/b and Height: {df_healthiest['(O2Sat - a)/b'].corr(df_healthiest.Height)}"
)

# Plot those residuals with height with trendline linera
fig = px.scatter(
    df_healthiest,
    x="Height - mean_height",
    # x="Height",
    y="(O2Sat - a)/b",
    trendline="ols",
    trendline_color_override="black",
)
fig.show()
# Out:
# /var/folders/zq/v2r6yn111s3gpdf8lzf72xvw0000gn/T/ipykernel_68361/2182756050.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/zq/v2r6yn111s3gpdf8lzf72xvw0000gn/T/ipykernel_68361/2182756050.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Correlation between (O2Sat - a)/b and Height: -0.09188207440222844
